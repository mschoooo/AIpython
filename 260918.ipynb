# %%
print('hello world')
# Out:
# hello world

# %%
#100분은 몇시간 몇분인지 출력해 보시오

# %%
print('100분은', 100//60, '시간', 100%60, '분 입니다')
# Out:
# 100분은 1 시간 40 분 입니다

# %%
time=100
print(time, '분은', time//60, '시간', time%60, '분 입니다')
# Out:
# 100 분은 1 시간 40 분 입니다

# %%
time = int(input('시간을 입력하세요: '))
print(time, '분은', time//60, '시간', time%60, '분 입니다')
# Out:
# 시간을 입력하세요:  200
# 200 분은 3 시간 20 분 입니다

# %%
time = int(input('시간을 입력하세요: '))
print(f'{time}분은 {time//60}시간 {time%60}분 입니다')
# Out:
# 시간을 입력하세요:  180
# 180분은 3시간 0분 입니다

# %%
#복합대입 연산자
a = 0
a = a + 7
a = a + 7
a = a + 7
a = a + 7
print(a)
# Out:
# 28

# %%
student_name = 1
#키워드는 변수로 안 쓴다

# %%
name = input('이름을 입력하세요: ')
age = int(input('나이을 입력하세요: '))
print(name, age)
# Out:
# 이름을 입력하세요:  조민성
# 나이을 입력하세요:  24
# 조민성 24

# %%
age=age+1

# %%
age
# Out:
# 26

# %%
if False:
    print("참")
else:
    print("거짓")
# Out:
# 거짓

# %%
#숫자를 입력받아서 짝수인지 홀수인지 출력하는 프로그램을 작성하시오

n = int(input("숫자를 입력하시오"))
if n%2 = 0
    print(짝수입니다)
else 
    print(홀수입니다)
# Out:
#   Cell In[67], line 4
#     if n%2 = 0
#        ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?
