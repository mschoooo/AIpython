# %%
print("2주차")
print(10+20)
# Out:
# 2주차
# 30

# %%
print(1+2)

# %%
a="2주차 코딩"
print(a)
# Out:
# 2주차 코딩

# %%
a=1
b=2
print(a+b)
print(a-b)
print(a/b)
print(a*b)
# Out:
# 3
# -1
# 0.5
# 2

# %%
#두 자연수 10와 5가 주어진다.
#이때, A+B,A-B,A*B,A/B(몫),A%B(나머지)를 출력하는 프로그램을 작성하시오.
A=5
B=10
print(A+B)
print(A-B)
print(A*B)
print(A/B)
print(A%B)
# Out:
# (5, 10, 5, 10)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_643/563540100.py in <cell line: 0>()
#       4 B=5, 10
#       5 print(A+B)
# ----> 6 print(A-B)
#       7 print(A*B)
#       8 print(A/B)
#
# TypeError: unsupported operand type(s) for -: 'tuple' and 'tuple'

# %%
#넓이가 12, 높이가 7인 직사각형의 넓이와 둘레를 구하시오
W=12
H=7
print(W*H)
print(2*W+2*H)
# Out:
# 84
# 38

# %%
#국어점수가 88, 영어점수가 92, 수학점수가 75인 사람의 평균점수는?
국어=88
영어=92
수학=75
총합=국어+영어+수학
print(총합/3)
# Out:
# 85.0
